# %% [markdown]
# # ПРОЕКТ "Активность R"
#
# ### Задача ПРОЕКТА:
#
# Проанализировать активность риелторов и выделить портреты риелторов по задаточной активности.

# %% [markdown]
# <div class="alert alert-info">
#
# ### Оглавление: <a id = 'section1'></a>
#
# #### [1. ОПИСАНИЕ И ЗАГРУЗКА ДАННЫХ](#step1)
#
# #### [2. ПРЕДОБРАБОТКА ДАННЫХ](#step2)
#
# #### [3. ИССЛЕДОВАТЕЛЬСКИЙ АНАЛИЗ ДАННЫХ (EDA)](#step3)
#
# #### [4. КЛАСТЕРИЗАЦИЯ РИЕЛТОРОВ](#step4)
#
# </div>

# %% [markdown]
# ## Шаг 1. ОПИСАНИЕ И ЗАГРУЗКА ДАННЫХ <a id="step1"></a>
#
# Датасет содержит данные об активности риелторов за ноябрь 2020 - февраль 2021 (срез на 19.02.2021)

# %%
#импорт необходимых библиотек
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import dates
import numpy as np
import scipy.stats as stats
import datetime as dt
import seaborn as sns

# %%
r = pd.read_excel('C:\\Этажи\\свод.xlsx')

# %% [markdown]
# <a href = '#section1'>Вернуться к оглавлению</a>
#
# ## Шаг 2. ПРЕДОБРАБОТКА ДАННЫХ <a id="step2"></a>
#
# замена пропущенных значений на 0

# %%
#просмотр данных таблицы
print(r.shape)
print()
print(r.info())
print()
print('Количество дубликатов в таблице:', r.duplicated().sum())
print()
print('Первые 5 строк датасета:')
display(r.head(5))
# Out:
# (9086, 44)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9086 entries, 0 to 9085
# Data columns (total 44 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Код Риелтора                         9086 non-null   int64
#  1   ФИО риелтора                         9086 non-null   object
#  2   город                                9086 non-null   object
#  3   стаж                                 0 non-null      float64
#  4   МОП                                  8755 non-null   object
#  5   Заходы в РИЭС нояб. 2020             8848 non-null   float64
#  6   Заходы в РИЭС дек. 2020              8987 non-null   float64
#  7   Заходы в РИЭС янв. 2021              9028 non-null   float64
#  8   Заходы в РИЭС февр. 2021             8988 non-null   float64
#  9   Заходы в РИЭС среднее н-ф            9086 non-null   float64
#  10  ВП дек. 2020                         8606 non-null   float64
#  11  ВП янв. 2021                         8614 non-null   float64
#  12  ВП февр. 2021                        8480 non-null   float64
#  13  ВП среднее д-ф                       9086 non-null   float64
#  14  Подборки дек. 2020                   6212 non-null   float64
#  15  Подборки янв. 2021                   6208 non-null   float64
#  16  Подборки февр. 2021                  6031 non-null   float64
#  17  Подборки среднее д-ф                 9086 non-null   float64
#  18  Показы дек. 2020                     204 non-null    float64
#  19  Показы янв. 2021                     690 non-null    float64
#  20  Показы февр. 2021                    2127 non-null   float64
#  21  Показы среднее д-ф                   9086 non-null   float64
#  22  Ипотечная консультация дек. 2020     3612 non-null   float64
#  23  Ипотечная консультация янв. 2021     3896 non-null   float64
#  24  Ипотечная консультация февр. 2021    2879 non-null   float64
#  25  Ипотечная консультация среднее д-ф   9086 non-null   float64
#  26  Набор базы нояб. 2020                7562 non-null   float64
#  27  Набор базы дек. 2020                 7383 non-null   float64
#  28  Набор базы янв. 2021                 7481 non-null   float64
#  29  Набор базы февр. 2021                6968 non-null   float64
#  30  Набор базы среднее н-ф               9086 non-null   float64
#  31  Затраты на рекламу нояб. 2020        9086 non-null   int64
#  32  Затраты на рекламу дек. 2020         9086 non-null   int64
#  33  Затраты на рекламу янв. 2021         9086 non-null   int64
#  34  Затраты на рекламу февр. 2021        9086 non-null   int64
#  35  Затраты на рекламу среднее н-ф       9086 non-null   float64
#  36  Изменение цены объектов нояб. 2020   7902 non-null   float64
#  37  Изменение цены объектов дек. 2020    7844 non-null   float64
#  38  Изменение цены объектов янв. 2021    7766 non-null   float64
#  39  Изменение цены объектов февр. 2021   7385 non-null   float64
#  40  Изменение цены объектов среднее н-ф  9086 non-null   float64
#  41  Кол-во задатков февр. 2021           9086 non-null   int64
#  42  Кластер R по задаткам                9086 non-null   object
#  43  ТОП                                  9086 non-null   int64
# dtypes: float64(33), int64(7), object(4)
# memory usage: 3.1+ MB
# None
#
# Количество дубликатов в таблице: 54
#
# Первые 5 строк датасета:
#    Код Риелтора                   ФИО риелтора         город  стаж  \
# 0          1232      Кремлев Владислав Юрьевич        Тюмень   NaN
# 1         18930      Пушкина Виктория Ивановна        Тюмень   NaN
# 2         14272       Ишкиев Ильнур Ильшатович        Тюмень   NaN
# 3         14888  Третьякова Екатерина Петровна        Тюмень   NaN
# 4         22415     Замошникова Ольга Петровна  Нижний Тагил   NaN
#
#                              МОП  Заходы в РИЭС нояб. 2020  \
# 0       Шарипов Фаниль Асхатович                     155.0
# 1     Фаттахов Артур Альбертович                       0.0
# 2       Ишкиев Ильнур Ильшатович                     200.0
# 3    Каримова Ильсеяр Равильевна                       0.0
# 4  Осинняя Татьяна Александровна                     105.0
#
#    Заходы в РИЭС дек. 2020  Заходы в РИЭС янв. 2021  Заходы в РИЭС февр. 2021  \
# 0                    111.0                    139.0                     104.0
# 1                      0.0                      0.0                       0.0
# 2                    210.0                    170.0                     132.0
# 3                      0.0                      0.0                       0.0
# 4                    106.0                     98.0                      76.0
#
#    Заходы в РИЭС среднее н-ф  ...  Затраты на рекламу февр. 2021  \
# 0                     127.25  ...                              0
# 1                       0.00  ...                           6488
# 2                     178.00  ...                           4832
# 3                       0.00  ...                           1611
# 4                      96.25  ...                           6810
#
#    Затраты на рекламу среднее н-ф  Изменение цены объектов нояб. 2020  \
# 0                          243.75                                22.0
# 1                         4318.75                                 4.0
# 2                         4596.00                                20.0
# 3                         2039.00                                 3.0
# 4                         7267.50                                16.0
#
#    Изменение цены объектов дек. 2020  Изменение цены объектов янв. 2021  \
# 0                               20.0                               11.0
# 1                               25.0                               21.0
# 2                               12.0                               26.0
# 3                                9.0                                8.0
# 4                                8.0                               36.0
#
#    Изменение цены объектов февр. 2021  Изменение цены объектов среднее н-ф  \
# 0                                10.0                                15.75
# 1                                 8.0                                14.50
# 2                                11.0                                17.25
# 3                                 5.0                                 6.25
# 4                                 4.0                                16.00
#
#    Кол-во задатков февр. 2021  Кластер R по задаткам  ТОП
# 0                          22            №4: более 8    1
# 1                          21            №4: более 8    1
# 2                          16            №4: более 8    1
# 3                          15            №4: более 8    1
# 4                          15            №4: более 8    1
#
# [5 rows x 44 columns]

# %%
#удалим дубликаты
r = r.drop_duplicates().reset_index(drop = True)

# %%
#выведем названия столбцов для дальнейшего использования
print(r.columns)
# Out:
# Index(['Код Риелтора', 'ФИО риелтора', 'город', 'стаж', 'МОП',
#        'Заходы в РИЭС нояб. 2020', 'Заходы в РИЭС дек. 2020',
#        'Заходы в РИЭС янв. 2021', 'Заходы в РИЭС февр. 2021',
#        'Заходы в РИЭС среднее н-ф', 'ВП дек. 2020', 'ВП янв. 2021',
#        'ВП февр. 2021', 'ВП среднее д-ф', 'Подборки дек. 2020',
#        'Подборки янв. 2021', 'Подборки февр. 2021', 'Подборки среднее д-ф',
#        'Показы дек. 2020', 'Показы янв. 2021', 'Показы февр. 2021',
#        'Показы среднее д-ф', 'Ипотечная консультация дек. 2020',
#        'Ипотечная консультация янв. 2021', 'Ипотечная консультация февр. 2021',
#        'Ипотечная консультация среднее д-ф', 'Набор базы нояб. 2020',
#        'Набор базы дек. 2020', 'Набор базы янв. 2021', 'Набор базы февр. 2021',
#        'Набор базы среднее н-ф', 'Затраты на рекламу нояб. 2020',
#        'Затраты на рекламу дек. 2020', 'Затраты на рекламу янв. 2021',
#        'Затраты на рекламу февр. 2021', 'Затраты на рекламу среднее н-ф',
#        'Изменение цены объектов нояб. 2020',
#        'Изменение цены объектов дек. 2020',
#        'Изменение цены объектов янв. 2021',
#        'Изменение цены объектов февр. 2021',
#        'Изменение цены объектов среднее н-ф', 'Кол-во задатков февр. 2021',
#        'Кластер R по задаткам', 'ТОП'],
#       dtype='object')

# %%
#отработаем пропущенные значения (кроме стажа) - заменим на 0
r[['МОП',
       'Заходы в РИЭС нояб. 2020', 'Заходы в РИЭС дек. 2020',
       'Заходы в РИЭС янв. 2021', 'Заходы в РИЭС февр. 2021',
       'Заходы в РИЭС среднее н-ф', 'ВП дек. 2020', 'ВП янв. 2021',
       'ВП февр. 2021', 'ВП среднее д-ф', 'Подборки дек. 2020',
       'Подборки янв. 2021', 'Подборки февр. 2021', 'Подборки среднее д-ф',
       'Показы дек. 2020', 'Показы янв. 2021', 'Показы февр. 2021',
       'Показы среднее д-ф', 'Ипотечная консультация дек. 2020',
       'Ипотечная консультация янв. 2021', 'Ипотечная консультация февр. 2021',
       'Ипотечная консультация среднее д-ф', 'Набор базы нояб. 2020',
       'Набор базы дек. 2020', 'Набор базы янв. 2021', 'Набор базы февр. 2021',
       'Набор базы среднее н-ф', 'Затраты на рекламу нояб. 2020',
       'Затраты на рекламу дек. 2020', 'Затраты на рекламу янв. 2021',
       'Затраты на рекламу февр. 2021', 'Затраты на рекламу среднее н-ф',
       'Изменение цены объектов нояб. 2020',
       'Изменение цены объектов дек. 2020',
       'Изменение цены объектов янв. 2021',
       'Изменение цены объектов февр. 2021',
       'Изменение цены объектов среднее н-ф']] = r[['МОП',
       'Заходы в РИЭС нояб. 2020', 'Заходы в РИЭС дек. 2020',
       'Заходы в РИЭС янв. 2021', 'Заходы в РИЭС февр. 2021',
       'Заходы в РИЭС среднее н-ф', 'ВП дек. 2020', 'ВП янв. 2021',
       'ВП февр. 2021', 'ВП среднее д-ф', 'Подборки дек. 2020',
       'Подборки янв. 2021', 'Подборки февр. 2021', 'Подборки среднее д-ф',
       'Показы дек. 2020', 'Показы янв. 2021', 'Показы февр. 2021',
       'Показы среднее д-ф', 'Ипотечная консультация дек. 2020',
       'Ипотечная консультация янв. 2021', 'Ипотечная консультация февр. 2021',
       'Ипотечная консультация среднее д-ф', 'Набор базы нояб. 2020',
       'Набор базы дек. 2020', 'Набор базы янв. 2021', 'Набор базы февр. 2021',
       'Набор базы среднее н-ф', 'Затраты на рекламу нояб. 2020',
       'Затраты на рекламу дек. 2020', 'Затраты на рекламу янв. 2021',
       'Затраты на рекламу февр. 2021', 'Затраты на рекламу среднее н-ф',
       'Изменение цены объектов нояб. 2020',
       'Изменение цены объектов дек. 2020',
       'Изменение цены объектов янв. 2021',
       'Изменение цены объектов февр. 2021',
       'Изменение цены объектов среднее н-ф']].fillna(0)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9032 entries, 0 to 9031
# Data columns (total 44 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Код Риелтора                         9032 non-null   int64
#  1   ФИО риелтора                         9032 non-null   object
#  2   город                                9032 non-null   object
#  3   стаж                                 0 non-null      float64
#  4   МОП                                  9032 non-null   object
#  5   Заходы в РИЭС нояб. 2020             9032 non-null   float64
#  6   Заходы в РИЭС дек. 2020              9032 non-null   float64
#  7   Заходы в РИЭС янв. 2021              9032 non-null   float64
#  8   Заходы в РИЭС февр. 2021             9032 non-null   float64
#  9   Заходы в РИЭС среднее н-ф            9032 non-null   float64
#  10  ВП дек. 2020                         9032 non-null   float64
#  11  ВП янв. 2021                         9032 non-null   float64
#  12  ВП февр. 2021                        9032 non-null   float64
#  13  ВП среднее д-ф                       9032 non-null   float64
#  14  Подборки дек. 2020                   9032 non-null   float64
#  15  Подборки янв. 2021                   9032 non-null   float64
#  16  Подборки февр. 2021                  9032 non-null   float64
#  17  Подборки среднее д-ф                 9032 non-null   float64
#  18  Показы дек. 2020                     9032 non-null   float64
#  19  Показы янв. 2021                     9032 non-null   float64
#  20  Показы февр. 2021                    9032 non-null   float64
#  21  Показы среднее д-ф                   9032 non-null   float64
#  22  Ипотечная консультация дек. 2020     9032 non-null   float64
#  23  Ипотечная консультация янв. 2021     9032 non-null   float64
#  24  Ипотечная консультация февр. 2021    9032 non-null   float64
#  25  Ипотечная консультация среднее д-ф   9032 non-null   float64
#  26  Набор базы нояб. 2020                9032 non-null   float64
#  27  Набор базы дек. 2020                 9032 non-null   float64
#  28  Набор базы янв. 2021                 9032 non-null   float64
#  29  Набор базы февр. 2021                9032 non-null   float64
#  30  Набор базы среднее н-ф               9032 non-null   float64
#  31  Затраты на рекламу нояб. 2020        9032 non-null   int64
#  32  Затраты на рекламу дек. 2020         9032 non-null   int64
#  33  Затраты на рекламу янв. 2021         9032 non-null   int64
#  34  Затраты на рекламу февр. 2021        9032 non-null   int64
#  35  Затраты на рекламу среднее н-ф       9032 non-null   float64
#  36  Изменение цены объектов нояб. 2020   9032 non-null   float64
#  37  Изменение цены объектов дек. 2020    9032 non-null   float64
#  38  Изменение цены объектов янв. 2021    9032 non-null   float64
#  39  Изменение цены объектов февр. 2021   9032 non-null   float64
#  40  Изменение цены объектов среднее н-ф  9032 non-null   float64
#  41  Кол-во задатков февр. 2021           9032 non-null   int64
#  42  Кластер R по задаткам                9032 non-null   object
#  43  ТОП                                  9032 non-null   int64
# dtypes: float64(33), int64(7), object(4)
# memory usage: 3.0+ MB

# %%
display(r.head(10))
# Out:
#    Код Риелтора                   ФИО риелтора         город  стаж  \
# 0          1232      Кремлев Владислав Юрьевич        Тюмень   NaN
# 1         18930      Пушкина Виктория Ивановна        Тюмень   NaN
# 2         14272       Ишкиев Ильнур Ильшатович        Тюмень   NaN
# 3         14888  Третьякова Екатерина Петровна        Тюмень   NaN
# 4         22415     Замошникова Ольга Петровна  Нижний Тагил   NaN
# 5         33412  Екимовских Елизавета Ивановна         Ирбит   NaN
# 6         25026   Каминский Владимир Сергеевич    Ялуторовск   NaN
# 7         44095  Кузнецов Владислав Аркадьевич         Муром   NaN
# 8         33861    Сухушин Владимир Николаевич        Тюмень   NaN
# 9         58235   Туманов Валерий Владимирович        Казань   NaN
#
#                               МОП  Заходы в РИЭС нояб. 2020  \
# 0        Шарипов Фаниль Асхатович                     155.0
# 1      Фаттахов Артур Альбертович                       0.0
# 2        Ишкиев Ильнур Ильшатович                     200.0
# 3     Каримова Ильсеяр Равильевна                       0.0
# 4   Осинняя Татьяна Александровна                     105.0
# 5     Стяжкин Виталий Анатольевич                      54.0
# 6         Захаров Юрий Михайлович                      48.0
# 7  Маркова Кристина Александровна                      64.0
# 8      Завершенюк Жанна Борисовна                       0.0
# 9       Новохацкая Алсу Гавазовна                       0.0
#
#    Заходы в РИЭС дек. 2020  Заходы в РИЭС янв. 2021  Заходы в РИЭС февр. 2021  \
# 0                    111.0                    139.0                     104.0
# 1                      0.0                      0.0                       0.0
# 2                    210.0                    170.0                     132.0
# 3                      0.0                      0.0                       0.0
# 4                    106.0                     98.0                      76.0
# 5                     51.0                     40.0                      31.0
# 6                     56.0                     58.0                      43.0
# 7                     83.0                     58.0                      42.0
# 8                      0.0                      0.0                       0.0
# 9                      0.0                      0.0                       0.0
#
#    Заходы в РИЭС среднее н-ф  ...  Затраты на рекламу февр. 2021  \
# 0                     127.25  ...                              0
# 1                       0.00  ...                           6488
# 2                     178.00  ...                           4832
# 3                       0.00  ...                           1611
# 4                      96.25  ...                           6810
# 5                      44.00  ...                              0
# 6                      51.25  ...                            299
# 7                      61.75  ...                             65
# 8                       0.00  ...                           3220
# 9                       0.00  ...                           6149
#
#    Затраты на рекламу среднее н-ф  Изменение цены объектов нояб. 2020  \
# 0                          243.75                                22.0
# 1                         4318.75                                 4.0
# 2                         4596.00                                20.0
# 3                         2039.00                                 3.0
# 4                         7267.50                                16.0
# 5                            0.00                                15.0
# 6                          303.75                                13.0
# 7                          437.50                                 7.0
# 8                         5651.25                                 5.0
# 9                         5910.75                                19.0
#
#    Изменение цены объектов дек. 2020  Изменение цены объектов янв. 2021  \
# 0                               20.0                               11.0
# 1                               25.0                               21.0
# 2                               12.0                               26.0
# 3                                9.0                                8.0
# 4                                8.0                               36.0
# 5                                6.0                                8.0
# 6                               45.0                                2.0
# 7                                8.0                                5.0
# 8                                0.0                                2.0
# 9                                9.0                                4.0
#
#    Изменение цены объектов февр. 2021  Изменение цены объектов среднее н-ф  \
# 0                                10.0                            15.750000
# 1                                 8.0                            14.500000
# 2                                11.0                            17.250000
# 3                                 5.0                             6.250000
# 4                                 4.0                            16.000000
# 5                                 7.0                             9.000000
# 6                                15.0                            18.750000
# 7                                10.0                             7.500000
# 8                                 4.0                             3.666667
# 9                                 4.0                             9.000000
#
#    Кол-во задатков февр. 2021  Кластер R по задаткам  ТОП
# 0                          22            №4: более 8    1
# 1                          21            №4: более 8    1
# 2                          16            №4: более 8    1
# 3                          15            №4: более 8    1
# 4                          15            №4: более 8    1
# 5                          15            №4: более 8    1
# 6                          14            №4: более 8    1
# 7                          14            №4: более 8    1
# 8                          13            №4: более 8    1
# 9                          13            №4: более 8    1
#
# [10 rows x 44 columns]

# %% [markdown]
# ,<a href = '#section1'>Вернуться к оглавлению</a>
#
# ## Шаг 3. ИССЛЕДОВАТЕЛЬСКИЙ АНАЛИЗ ДАННЫХ (EDA) <a id="step3"></a>
#
# #### 3.1. Изучение основных статистик в табличном виде:
#
# - для начала посмотрим по всему датасету: средние, минимальные, максимальные значения, медиана, стандартные отклонения
# - далее посмотрим на статистики (средние и медиана) по группам риелторов — ТОП и не ТОП
#
# #### 3.2. Визуализация распределений. Возможно, какие-то закономерности сразу будут видны:
#
# - построим графики совместного распределения для переменных по группам риелторов — ТОП и не ТОП
# - построим гистограммы распределения признаков по группам риелторов — ТОП и не ТОП
#
# #### 3.3. Поиск корреляций
# - построим матрицу корреляций и отобразим её на тепловой карте

# %%
#Основные статистики датасета:
pd.set_option('display.max_columns', None)
display(r.describe())
# Out:
#        Код Риелтора  стаж  Заходы в РИЭС нояб. 2020  Заходы в РИЭС дек. 2020  \
# count  9.032000e+03   0.0               9032.000000              9032.000000
# mean   1.574027e+07   NaN                 36.095438                35.781554
# std    1.351083e+08   NaN                 39.756564                38.170534
# min    6.700000e+01   NaN                  0.000000                 0.000000
# 25%    2.696750e+04   NaN                  0.000000                 0.000000
# 50%    4.682750e+04   NaN                 31.000000                32.000000
# 75%    5.725025e+04   NaN                 60.000000                59.000000
# max    1.231219e+09   NaN                362.000000               371.000000
#
#        Заходы в РИЭС янв. 2021  Заходы в РИЭС февр. 2021  \
# count              9032.000000               9032.000000
# mean                 31.072298                 24.931023
# std                  33.914268                 26.582685
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                  27.000000                 22.000000
# 75%                  50.000000                 41.000000
# max                 343.000000                288.000000
#
#        Заходы в РИЭС среднее н-ф  ВП дек. 2020  ВП янв. 2021  ВП февр. 2021  \
# count                9032.000000   9032.000000   9032.000000    9032.000000
# mean                   32.340336     25.082042     25.476196      19.819973
# std                    33.075921     29.089711     28.501277      22.679482
# min                     0.000000      0.000000      0.000000       0.000000
# 25%                     0.000000      9.000000      9.000000       7.000000
# 50%                    30.750000     18.000000     19.000000      15.000000
# 75%                    52.250000     32.000000     33.000000      26.000000
# max                   294.250000    629.000000    668.000000     580.000000
#
#        ВП среднее д-ф  Подборки дек. 2020  Подборки янв. 2021  \
# count     9032.000000         9032.000000         9032.000000
# mean        23.671446           12.075509           12.533658
# count                     9032.000000                         9032.000000
# mean                      1459.983891                            5.637733
# std                       2132.151564                           10.391818
# min                          0.000000                            0.000000
# 25%                         62.687500                            1.000000
# 50%                        730.000000                            3.000000
# 75%                       1926.062500                            7.000000
# max                      25041.500000                          248.000000
#
#        Изменение цены объектов дек. 2020  Изменение цены объектов янв. 2021  \
# count                        9032.000000                        9032.000000
# mean                            5.155447                           4.771701
# std                             8.734774                           8.304639
# min                             0.000000                           0.000000
# 25%                             1.000000                           0.000000
# 50%                             3.000000                           3.000000
# 75%                             6.000000                           6.000000
# max                           170.000000                         218.000000
#
#        Изменение цены объектов февр. 2021  \
# count                         9032.000000
# mean                             3.507529
# std                              5.672975
# min                              0.000000
# 25%                              0.000000
# 50%                              2.000000
# 75%                              5.000000
# max                            136.000000
#
#        Изменение цены объектов среднее н-ф  Кол-во задатков февр. 2021  \
# count                          9032.000000                 9032.000000
# mean                              5.204237                    1.504207
# std                               7.236448                    1.957240
# min                               0.000000                    0.000000
# 25%                               2.000000                    0.000000
# 50%                               3.500000                    1.000000
# 75%                               6.250000                    2.000000
# max                             136.000000                   22.000000
#
#                ТОП
# count  9032.000000
# mean      0.002768
# std       0.052541
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
#посмотрим на медиану по группам риелторов — ТОП и не ТОП
pd.set_option('display.max_columns', None)
m = r.groupby(['ТОП']).median().round(0).T
#m['отношение ТОП к не ТОП'] = m['1']/m['0']
m.info()
m
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, Код Риелтора to Кол-во задатков февр. 2021
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       38 non-null     float64
#  1   1       38 non-null     float64
# dtypes: float64(2)
# memory usage: 2.2+ KB
# ТОП                                        0        1
# Код Риелтора                         46852.0  32202.0
# стаж                                     NaN      NaN
# Заходы в РИЭС нояб. 2020                31.0     53.0
# Заходы в РИЭС дек. 2020                 32.0     51.0
# Заходы в РИЭС янв. 2021                 27.0     46.0
# Заходы в РИЭС февр. 2021                22.0     43.0
# Заходы в РИЭС среднее н-ф               31.0     48.0
# ВП дек. 2020                            18.0     19.0
# ВП янв. 2021                            19.0     24.0
# ВП февр. 2021                           15.0     20.0
# ВП среднее д-ф                          18.0     22.0
# Подборки дек. 2020                       6.0     16.0
# Подборки янв. 2021                       6.0     15.0
# Подборки февр. 2021                      4.0     16.0
# Подборки среднее д-ф                     7.0     17.0
# Показы дек. 2020                         0.0      0.0
# Показы янв. 2021                         0.0      0.0
# Показы февр. 2021                        0.0      4.0
# Показы среднее д-ф                       0.0      4.0
# Ипотечная консультация дек. 2020         0.0      1.0
# Ипотечная консультация янв. 2021         0.0      2.0
# Ипотечная консультация февр. 2021        0.0      1.0
# Ипотечная консультация среднее д-ф       1.0      2.0
# Набор базы нояб. 2020                    4.0      6.0
# Набор базы дек. 2020                     4.0      8.0
# Набор базы янв. 2021                     4.0      6.0
# Набор базы февр. 2021                    2.0      6.0
# Набор базы среднее н-ф                   4.0      8.0
# Затраты на рекламу нояб. 2020          508.0   1598.0
# Затраты на рекламу дек. 2020           602.0   1438.0
# Затраты на рекламу янв. 2021           719.0   2043.0
# Затраты на рекламу февр. 2021          400.0   1611.0
# Затраты на рекламу среднее н-ф         727.0   1892.0
# Изменение цены объектов нояб. 2020       3.0      6.0
# Изменение цены объектов дек. 2020        3.0      9.0
# Изменение цены объектов янв. 2021        3.0      8.0
# Изменение цены объектов февр. 2021       2.0      5.0
# Изменение цены объектов среднее н-ф      4.0      9.0
# Кол-во задатков февр. 2021               1.0     12.0

# %% [markdown]
# <a href = '#section1'>Вернуться к оглавлению</a>
#
# ### 3.2. Визуализация распределений по группам риелторов — ТОП и не ТОП<a id="step3.3"></a>
#
# - построим графики распределения признаков по группам риелторов — ТОП и не ТОП
# - возможно, какие-то закономерности сразу будут видны

# %%
#создадим список с названиями столбцов средних величин
avg_value = [
       'Заходы в РИЭС среднее н-ф', 'ВП среднее д-ф', 'Подборки среднее д-ф',
       'Показы среднее д-ф', 'Ипотечная консультация среднее д-ф', 
       'Набор базы среднее н-ф', 'Затраты на рекламу среднее н-ф',
       'Изменение цены объектов среднее н-ф', 'Кол-во задатков февр. 2021']

# %%
#построим гистограммы по средним величинам
for column in avg_value:
    sns.distplot(r.query('ТОП == 0')[column], kde_kws={"color": "r", "label": "не ТОП"}, hist_kws={"color": "r"}) 
    sns.distplot(r.query('ТОП == 1')[column], kde_kws={"color": "b", "label": "ТОП"}, hist_kws={"color": "b"}) 
    plt.show();

# %% [markdown]
# <a href = '#section1'>Вернуться к оглавлению</a>
#
# ### 3.3. Поиск корреляций <a id="step3.4">
# - построим матрицу корреляций и отобразим её на тепловой карте

# %%
r1 = r.drop(['стаж', 
       'Заходы в РИЭС среднее н-ф', 'ВП среднее д-ф', 'Подборки среднее д-ф',
       'Показы среднее д-ф', 'Ипотечная консультация среднее д-ф', 
       'Набор базы среднее н-ф', 'Затраты на рекламу среднее н-ф',
       'Изменение цены объектов среднее н-ф', 'Кластер R по задаткам', 'ТОП'], 1)

# %%
#расчёт корреляций
cor = r1.corr()

# %%
#нарисуем тепловую карту с подписями для матрицы корреляций
plt.figure(figsize=(25, 25))
plt.title('Тепловая карта корреляции')
sns.heatmap(cor, annot = True, square=True, cmap="YlGnBu", fmt='.3f', linewidths=1, linecolor='white');

# %% [markdown]
# <a href = '#section1'>Вернуться к оглавлению</a>
#
# ## Шаг 4. КЛАСТЕРИЗАЦИЯ РИЕЛТОРОВ<a id="step4"></a>
#
# - Стандартизируем данные.
# - Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуем дендрограмму.
# Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.
# - Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры риелторов.
# - Посмотрим на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
# - Построим распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
#зададим вектор целевой переменной
y = r1['Кол-во задатков февр. 2021']

# %%
#Создадим матрица "объект-признак"
X = r1.drop((['ФИО риелтора' , 'город', 'МОП', 'Кол-во задатков февр. 2021']), axis =1)

# %% [markdown]
# В sklearn для стандартизации данных в модуле preprocessing есть готовый класс `StandardScaler()`

# %%
#импорт класса StandardScaler() из библиотеки sklearn
from sklearn.preprocessing import StandardScaler

#создаём объект класса scaler
scaler = StandardScaler() 

# стандартизируем данные
X_sc = scaler.fit_transform(X)

# %%
#импортируем классы модели кластеризации linkage() и dendrogram() из модуля для иерархической кластеризации hierarchy:
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
#передадим получившуюся стандартизированную таблицу в качестве параметра функции linkage(). 
#Чтобы диаграмма получилась показательной, лучше передать параметру method значение 'ward'
linked = linkage(X_sc, method = 'ward')

# %%
#В переменной linked сохранена таблица «связок» между объектами. Её можно визуализировать как дендрограмму:
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# Дендрограмма построена. Автоматически определилось 3 кластера (3 цвета)
# Но опытным путем выявлено, что 3 кластера недостаточно, я попробую разбить риелторов на большее кол-во групп.

# %% [markdown]
# **K-Means (англ. «К средних»)**
#
# K-Means группирует объекты пошагово. Алгоритм основан на предположении, что число кластеров (групп) заранее известно. Вот принцип работы пошагового алгоритма K-means:
#
# 1) Есть K кластеров. Алгоритм пошагово подбирает их центры и относит объекты к тому кластеру, чей центр ближе.
#
# 2) Центры корректируются (меняют своё положение) до тех пор, пока это позволяет минимизировать среднее расстояние от объектов каждого кластера до его центра.
#
# 3) Когда расстояние от объектов до центра перестаёт снижаться или сокращается несущественно, алгоритм останавливается и фиксирует разбиение, считая его оптимальным.

# %%
#импортируем алгоритм KMeans из модуля sklearn.cluster
from sklearn.cluster import KMeans

#задаём число кластеров, равное 7
km = KMeans(n_clusters = 7, random_state=0) 

#применим алгоритм к данным, сформируем вектор кластеров. В переменной labels сохраняются индексы предложенных алгоритмом групп 
labels = km.fit_predict(X_sc)

# %%
#добавим столбец отметкой о принадлежности к кластеру в наш исходный датасет
r['clusters'] = labels
display(r)
# Out:
#       Код Риелтора                   ФИО риелтора         город  стаж  \
# 0             1232      Кремлев Владислав Юрьевич        Тюмень   NaN
# 1            18930      Пушкина Виктория Ивановна        Тюмень   NaN
# 2            14272       Ишкиев Ильнур Ильшатович        Тюмень   NaN
# 3            14888  Третьякова Екатерина Петровна        Тюмень   NaN
# 4            22415     Замошникова Ольга Петровна  Нижний Тагил   NaN
# ...            ...                            ...           ...   ...
# 9027    1231218767      Лысых Вероника Викторовна      Белгород   NaN
# 9028    1231218776      Шаталова Наталья Павловна         Тверь   NaN
# 9029    1231218795      Калугин Михаил Михайлович         Тверь   NaN
# 9030    1231218918         Валитов Булат Мусаевич     Новая Уфа   NaN
# 9031    1231218926      Самигуллин Флюр Рамилевич       Салават   NaN
#
#                                 МОП  Заходы в РИЭС нояб. 2020  \
# 0          Шарипов Фаниль Асхатович                     155.0
# 1        Фаттахов Артур Альбертович                       0.0
# 2          Ишкиев Ильнур Ильшатович                     200.0
# 3       Каримова Ильсеяр Равильевна                       0.0
# 4     Осинняя Татьяна Александровна                     105.0
# ...                             ...                       ...
# 9027                              0                       0.0
# 9028      Шаталова Наталья Павловна                       0.0
# 9029      Калугин Михаил Михайлович                      67.0
# 9030  Лебедь Кристина Владиславовна                      10.0
# 9031                              0                       0.0
#
#       Заходы в РИЭС дек. 2020  Заходы в РИЭС янв. 2021  \
#
#      Кластер R по задаткам  ТОП  clusters
# 0              №4: более 8    1         5
# 1              №4: более 8    1         2
# 2              №4: более 8    1         5
# 3              №4: более 8    1         4
# 4              №4: более 8    1         1
# ...                    ...  ...       ...
# 9027      №1: нет задатков    0         6
# 9028      №1: нет задатков    0         6
# 9029      №1: нет задатков    0         6
# 9030      №1: нет задатков    0         6
# 9031      №1: нет задатков    0         6
#
# [9032 rows x 45 columns]

# %% [markdown]
# ### ВЫВОД
#
# Кластеры риелторов спрогнозированы. Столбец с отметкой о принадлежности к кластеру добавлен в исходный датасет
#
# Далее можно посмотреть на средние значения признаков в разбивке по кластерам, поискать особенности и закономерности.

# %% [markdown]
# Посмотрим визуально, как распределились признаки по кластерам:
#
# - построим боксплоты для количественных переменных и бар-чарты для категориальных;
# - для каждой переменной покажем 1 график, на котором разными цветами отобразим результаты для каждого из кластеров.

# %%
#построим боксплоты для средних величин
for column in avg_value:
    sns.boxplot(x = 'clusters', y = column, data = r)
    plt.xlabel('кластер')
    plt.ylabel(column)
    plt.title('Распределение {} по кластерам'.format(column)) 
    plt.show();

# %%
r.groupby(['clusters']).median().round(2).T
# Out:
# clusters                                    0         1         2         3  \
# Код Риелтора                         43727.00  46259.00  52925.50  53629.00
# стаж                                      NaN       NaN       NaN       NaN
# Заходы в РИЭС нояб. 2020                 0.00     38.00      0.00     45.00
# Заходы в РИЭС дек. 2020                  0.00     36.00      0.00     52.00
# Заходы в РИЭС янв. 2021                  0.00     29.00      0.00     53.00
# Заходы в РИЭС февр. 2021                 0.00     24.00      0.00     43.00
# Заходы в РИЭС среднее н-ф                3.00     34.00      0.00     51.67
# ВП дек. 2020                            10.00     36.00     31.00     99.00
# ВП янв. 2021                            10.00     36.00     33.00     94.00
# ВП февр. 2021                            8.00     27.00     26.00     75.00
# ВП среднее д-ф                          10.33     34.33     31.67     91.00
# Подборки дек. 2020                       1.00      3.00     13.00      3.00
# Подборки янв. 2021                       1.00      3.00     14.00      4.00
# Подборки февр. 2021                      0.00      2.00     12.00      2.00
# Подборки среднее д-ф                     2.67      4.67     15.00      5.00
# Показы дек. 2020                         0.00      0.00      0.00      0.00
# Показы янв. 2021                         0.00      0.00      0.00      0.00
# Показы февр. 2021                        0.00      0.00      0.00      0.00
# Показы среднее д-ф                       0.00      0.00      0.00      0.00
# Ипотечная консультация дек. 2020         0.00      1.00      1.00      0.00
# Ипотечная консультация янв. 2021         0.00      1.00      1.00      0.00
# Ипотечная консультация февр. 2021        0.00      0.00      0.00      0.00
# Ипотечная консультация среднее д-ф       0.00      1.50      1.50      0.00
# Набор базы нояб. 2020                    2.00     10.00      7.00     29.00
# Набор базы дек. 2020                     1.00      9.00      8.00     32.00
# Набор базы янв. 2021                     1.00      8.00      8.00     30.00
# Набор базы февр. 2021                    1.00      5.00      5.00     20.00
# Набор базы среднее н-ф                   2.50      9.00      8.00     31.25
# Затраты на рекламу нояб. 2020          107.00   7420.00    568.50      0.00
# Затраты на рекламу дек. 2020           112.00   7430.00    900.00      0.00
# Затраты на рекламу янв. 2021           182.00   7570.00    981.00      0.00
# Затраты на рекламу февр. 2021           32.00   5500.00    690.50      0.00
# Затраты на рекламу среднее н-ф         262.00   6794.25   1027.38      0.00
# Изменение цены объектов нояб. 2020       1.00     10.00      4.00     36.00
# Изменение цены объектов дек. 2020        1.00      9.00      5.00     34.00
# Изменение цены объектов янв. 2021        1.00      8.00      4.50     32.00
# Изменение цены объектов февр. 2021       1.00      5.00      4.00     20.00
# Изменение цены объектов среднее н-ф      2.00      9.00      5.25     33.00
# Кол-во задатков февр. 2021               0.00      1.00      1.00      2.00
# ТОП                                      0.00      0.00      0.00      0.00
#
# clusters                                    4         5             6
# Код Риелтора                         48432.50  43368.00  1.231215e+09
# стаж                                      NaN       NaN           NaN
# Заходы в РИЭС нояб. 2020                60.50     71.00  0.000000e+00
# Заходы в РИЭС дек. 2020                 61.50     68.00  0.000000e+00
# Заходы в РИЭС янв. 2021                 55.50     58.00  0.000000e+00
# Заходы в РИЭС февр. 2021                43.00     47.00  0.000000e+00
# Заходы в РИЭС среднее н-ф               56.88     61.25  0.000000e+00
# ВП дек. 2020                            26.00     19.00  1.000000e+00
# ВП янв. 2021                            28.00     21.00  0.000000e+00
# ВП февр. 2021                           21.00     16.00  1.000000e+00
# ВП среднее д-ф                          25.33     19.33  1.500000e+00
# Подборки дек. 2020                      43.00     10.00  0.000000e+00
# Подборки янв. 2021                      48.00     10.00  0.000000e+00
# Подборки февр. 2021                     39.00      8.00  0.000000e+00
# Подборки среднее д-ф                    46.50     11.00  0.000000e+00
# Показы дек. 2020                         0.00      0.00  0.000000e+00
# Показы янв. 2021                         0.00      0.00  0.000000e+00
# Показы февр. 2021                        3.00      0.00  0.000000e+00
# Показы среднее д-ф                       4.00      0.00  0.000000e+00
# Ипотечная консультация дек. 2020         1.00      0.00  0.000000e+00
# Ипотечная консультация янв. 2021         2.00      0.50  0.000000e+00
# Ипотечная консультация февр. 2021        1.00      0.00  0.000000e+00
# Ипотечная консультация среднее д-ф       2.00      1.00  0.000000e+00
# Набор базы нояб. 2020                    5.00      5.00  0.000000e+00
# Набор базы дек. 2020                     5.00      4.00  0.000000e+00
# Набор базы янв. 2021                     5.00      4.00  0.000000e+00
# Набор базы февр. 2021                    3.00      3.00  0.000000e+00
# Набор базы среднее н-ф                   5.25      4.50  0.000000e+00
# Затраты на рекламу нояб. 2020         1627.50    978.00  0.000000e+00
# Затраты на рекламу дек. 2020          1671.50   1000.00  0.000000e+00
# Затраты на рекламу янв. 2021          1781.00   1155.00  0.000000e+00
# Затраты на рекламу февр. 2021         1290.50    699.50  0.000000e+00
# Затраты на рекламу среднее н-ф        1771.25   1117.50  0.000000e+00
# Изменение цены объектов нояб. 2020       5.00      4.00  0.000000e+00
# Изменение цены объектов дек. 2020        5.00      4.00  0.000000e+00
# Изменение цены объектов янв. 2021        5.00      4.00  0.000000e+00
# Изменение цены объектов февр. 2021       3.00      3.00  0.000000e+00
# Изменение цены объектов среднее н-ф      5.50      4.25  0.000000e+00
# Кол-во задатков февр. 2021               3.00      1.00  0.000000e+00
# ТОП                                      0.00      0.00  0.000000e+00

# %%
r.to_excel("output.xlsx")
